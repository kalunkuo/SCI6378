# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set()
sns.set_style("whitegrid")

get_ipython().run_line_magic('precision', '3')
pd.set_option('precision', 3)

# Enable Jupyter Notebook's intellisense
get_ipython().run_line_magic('config', 'IPCompleter.greedy=True')

df = pd.read_csv('data_bike/2020-date.csv', parse_dates=['Date'])
df_all = df.set_index(["Date"], inplace=False)

fig, ax = plt.subplots(figsize=(30,10))
sns.lineplot(data=df_all, x="Date", y="count", hue="Borough")

ax.set(xlabel="Date", ylabel="count", title="biking")
# Out:
# [Text(0.5, 0, 'Date'), Text(0, 0.5, 'count'), Text(0.5, 1.0, 'biking')]

# %%
import numpy as np

df = pd.read_csv('data_bike/citibike_population density.csv')
sns.heatmap(df.corr(), cmap="BuPu_r", annot = True)
# Out:
# <AxesSubplot:>

# %%
file_path='data_bike/correlation0414.csv'
pd = pd.read_csv(file_path)
pd.head()
# Out:
#    citibike        borough  poverty  population   density
# 0    586.53      Manhattan     14.8     1577385  73709.58
# 1      9.17          Bronx     27.3     1380697  38566.96
# 2    160.11       Brooklyn     19.7     2504609  39195.76
# 3     32.44         Queens     17.2     2241021  23639.46
# 4       NaN  Staten Island     14.7      467968   8312.04

# %%
g = sns.PairGrid(pd, hue="borough", palette='PRGn')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g = g.add_legend()
plt.savefig('scatterplotchart.pdf', dpi=300,bbox_inches="tight")
